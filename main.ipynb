# %%
# !pip install psycopg2

# %%
import psycopg2

# %%
try:
     conn = psycopg2.connect("host= localhost dbname=postgres user=postgresql password=postgres")
        
except psycopg2.Error as e:
    print("Could not connect")
    print(e)

# %%
try:
    cur = conn.cursor()
    
except psycopg2.Error as e:
    print("Could not connect")
    print(e)

# %%
conn.set_session(autocommit=True)

# %%
try:
    cur.execute("create database new")
    
except psycopg2.Error as e:
    print("Could not create")
    print(e)

# %%
try: 
    conn.close()
    
except psycopg2.Error as e:
    print(e)
    
try:
     conn = psycopg2.connect("host= localhost dbname=myfirstdb user=postgresql password=postgres")
     print("connected")

except psycopg2.Error as e:
    print("Could not connect")
    print(e)
    
try:
    cur = conn.cursor()
    
except psycopg2.Error as e:
    print("Could not connect")
    print(e)

conn.set_session(autocommit=True)
# Out:
# connected

# %%
try:
    cur.execute("CREATE TABLE IF NOT EXISTS students (student_id int, name varchar, age int, gender varchar, \
                 subject varchar, marks int);")
    
except psycopg2.Error as e:
    print("Could not create Table")
    print(e)

# %%
try:
    cur.execute("INSERT INTO students(student_id,name,age,gender,subject,marks) \
                VALUES(%s,%s,%s,%s,%s,%s)",(12,"Ifra", 21, "female", "DE", 80))
    
except psycopg2.Error as e:
    print("Could not create rows")
    print(e)
    
try:
    cur.execute("INSERT INTO students(student_id,name,age,gender,subject,marks) \
                VALUES(%s,%s,%s,%s,%s,%s)",(13,"Ayesha", 20, "female", "DE", 85))
    
except psycopg2.Error as e:
    print("Could not create rows")
    print(e)
